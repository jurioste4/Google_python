# %% [markdown]
# ## Unhandled Errors  and Exceptions
#
#
#
#
#
# ### Resources for Debugging Crashes
#
# Check out the following links for more information:
#
#     https://realpython.com/python-concurrency/
#
#     https://hackernoon.com/threaded-asynchronous-magic-and-how-to-wield-it-bba9ed602c32
#
#     https://stackoverflow.com/questions/33047452/definitive-list-of-common-reasons-for-segmentation-faults
#
#     https://sites.google.com/a/case.edu/hpcc/home/important-notes-for-new-users/debugging-segmentation-faults
#
# Readable Python code on GitHub:
#
#     https://github.com/fogleman/Minecraft
#
#     https://github.com/cherrypy/cherrypy
#
#     https://github.com/pallets/flask
#
#     https://github.com/tornadoweb/tornado
#
#     https://github.com/gleitz/howdoi
#
#     https://github.com/bottlepy/bottle/blob/master/bottle.py
#
#     https://github.com/sqlalchemy/sqlalchemy

# %% [markdown]
# #### Unhandle Errors
#
# Traceback : Shows the lines of the different functions that were being execurited when the problem happened:
#
# when traceback is not enufe  you  can use the built in debugger :
#
# for python it is called : pdb :  sets the debugging to be active
#
# also common  to add statments that print data related to the codes execution
#
# this techneque is called : printf debugging
#
# you want to add these in a way to  be able to dis able or enable them when needed and you use the : logging  modual

# %% [markdown]
# ### fixing Someone Else's Code
#
# Core Files : store all the inforamtion related to the crash so that we or someone else , can debug what going on.
#
# ###### program faluts with a Segmentation fault
#
# so tell the os to  create core files, with the command
#
# ulimit -c unlimited  < enter >
#
# then run the program ;
# ( out put ) sementation fault (core dumped)
#
# : then  find the file with :  ls -l core
#
# so can understand why the program  crashed by passing it thew the : gdb debugger ;
#
# gdb -c core example
#
#
#  look at the full backtrace of the crash by using the backtrace command.
#
# backtrace
#
# : The first element in
# the list is the function where the crash occurred.
# The second element is
# the function that called the function and so on

# %% [markdown]
# #### Python crash debugging :
#
# so with python  looking at unexpected exceptions :
# Exsample :
#
# At the bottom, we see the name of the exception.
# In this case, Key Error and the message in this case,
# product code, which is
# the name of the key that's failing.
# Above that, we see a list of function
# calls with two lines per function.
# The first line tells us
# the Python file that contains the function,
# the line number, and the name of the function.
# The second line shows us the contents of that line.
# This information is similar to
# the back-trace that we saw in our last video.
# But the order of the functions is reversed.
#
#
# so will use : pdb3 library
#
# so exacute by typeing
#
# pdb3 python_script.py data_file.csv
#
# then run  continue  : runs the command as it should ..
