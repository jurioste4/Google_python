# %% [markdown]
# ### Intro to Module 2: Slowness

# %% [markdown]
# use : #####AB : it is an apache benchmark tool:
# will make requests to the website and get the average timeing . of the request .
#
# ab -n 500
#
#
#
# so  check the web servuer   and run  : #####top .. and check the prossess
#
#
# then look for the average load time : if to high .. can see what program is takeing most of the CPU time.
#
# change the prossess priortary , the lower the number the higher the priortary
#
# defalut is 0 .. and go to 0 to 19
#
# so change this priortary with command
#
# nice : changes the command priorotary
#
# renice : change priorary of a program already runnning .
#
#
#
# use a bashe script tp change it;
#
# pidof command :
#
# for pid in $(pidof ffmpeg); do renice 19 $pid; done
#
#
# :
#
# ps ax command : shows the running commands on the pcomputer..
# then use it with the less command
#
# so
#
# ps ax | less
#
#
# to find a file or use locate  command :
#
# locate static/001.webm
# output: /sr/deploy_videos/static/001.webm
#
#
# now can go to that folder .. to check all the files for  who is causeing the issue .. can
#
# use grep command :
#
# grep ffmpeg *
#
# descovery the program is running  the files in parralell useing a pross calld daemonize.
#
#
# Daemonize : runs each program  sepreitly
#
# but for a lot of files can over load the server .
#
#
# so after changeing  the files.
#
# to change the porssess currenly running : use
#
# killall command
#
# so
#
# killall -STOP  ffmpeg
#
#
# now want to run each of those c prossess one at a time .. how to do that .
#
# use same for loop like before;
#
# for pid in $(pidof ffmpeg); do while kill -CONT $pid; do sleep 1; done ; done

# %% [markdown]
# ####  Monitoring Tools
#
# Check out the following links for more information:
#
#     https://docs.microsoft.com/en-us/sysinternals/downloads/procmon
#
#     http://www.brendangregg.com/linuxperf.html
#
#     http://brendangregg.com/usemethod.html
#
#     Activity Monitor in Mac:
#
#     Performance Monitor on Windows
#
#     https://www.digitalcitizen.life/how-use-resource-monitor-windows-7
#
#     https://docs.microsoft.com/en-us/sysinternals/downloads/process-explorer
#
#     https://en.wikipedia.org/wiki/Cache_(computing)
#
#     https://www.reddit.com/r/linux/comments/d7hx2c/why_nice_levels_are_a_placebo_and_have_been_for_a/
